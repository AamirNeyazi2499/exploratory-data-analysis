# %% [markdown]
# ## Intro to Dataframes

# %%
import pandas as pd
df = pd.DataFrame([[1, 2, 3], [4, 5, 6], [7, 8, 9]] , columns =["A", "B", "C"], index=["X", "Y", "Z"])
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.1 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\Aamir Neyazi\AppData\Roaming\Python\Python312\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "C:\Users\Aamir Neyazi\AppData\Roaming\Python\Python312\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
# ...

# %%
df
# df.head(1) :- top row,  df.head(2) :- first two rows
# df.tail(2) :- bottom two rows
# Out:
#    A  B  C
# X  1  2  3
# Y  4  5  6
# Z  7  8  9

# %% [markdown]
# ## Loading in Dataframes from Files

# %%
coffee = pd.read_csv('coffee.csv')
nocs = pd.read_csv('noc_regions.csv')
results = pd.read_csv('results.csv')
bios = pd.read_csv('bios.csv')

# %%
olympics_data = pd.read_excel('olympics-data.xlsx', sheet_name="results")

# %%
olympics_data.head()
# Out:
#      year    type discipline                     event                     as  \
# 0  1912.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 1  1912.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
# 2  1920.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 3  1920.0  Summer     Tennis  Doubles, Mixed (Olympic)  Jean-François Blanchy
# 4  1920.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
#
#    athlete_id  noc             team  place   tied medal
# 0           1  FRA              NaN   17.0   True   NaN
# 1           1  FRA   Jean Montariol    NaN  False   NaN
# 2           1  FRA              NaN   32.0   True   NaN
# 3           1  FRA  Jeanne Vaussard    8.0   True   NaN
# 4           1  FRA  Jacques Brugnon    4.0  False   NaN

# %% [markdown]
# ## Accessing Data with Pandas

# %%
coffee.loc[:, ["Day", "Units Sold"]]
# Out:
#           Day  Units Sold
# 0      Monday          25
# 1      Monday          15
# 2     Tuesday          30
# 3     Tuesday          20
# 4   Wednesday          35
# 5   Wednesday          25
# 6    Thursday          40
# 7    Thursday          30
# 8      Friday          45
# 9      Friday          35
# 10   Saturday          45
# 11   Saturday          35
# 12     Sunday          45
# 13     Sunday          35

# %%
coffee.sort_values("Units Sold", ascending= False)
# Out:
#           Day Coffee Type  Units Sold
# 10   Saturday    Espresso          45
# 8      Friday    Espresso          45
# 12     Sunday    Espresso          45
# 6    Thursday    Espresso          40
# 4   Wednesday    Espresso          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 9      Friday       Latte          35
# 2     Tuesday    Espresso          30
# 7    Thursday       Latte          30
# 0      Monday    Espresso          25
# 5   Wednesday       Latte          25
# 3     Tuesday       Latte          20
# 1      Monday       Latte          15

# %%
for index, row in coffee.iterrows():
    print(index)
    print(row)
    print("\n")
# Out:
# 0
# Day              Monday
# Coffee Type    Espresso
# Units Sold           25
# Name: 0, dtype: object
#
#
# 1
# Day            Monday
# Coffee Type     Latte
# Units Sold         15
# Name: 1, dtype: object
#
#
# 2
# Day             Tuesday
# Coffee Type    Espresso
# Units Sold           30
# Name: 2, dtype: object
#
#
# 3
# Day            Tuesday
# Coffee Type      Latte
# Units Sold          20
# Name: 3, dtype: object
#
#
# 4
# Day            Wednesday
# Coffee Type     Espresso
# Units Sold            35
# Name: 4, dtype: object
#
#
# 5
# Day            Wednesday
# Coffee Type        Latte
# Units Sold            25
# Name: 5, dtype: object
#
#
# 6
# Day            Thursday
# Coffee Type    Espresso
# Units Sold           40
# Name: 6, dtype: object
#
#
# 7
# Day            Thursday
# Coffee Type       Latte
# Units Sold           30
# Name: 7, dtype: object
#
#
# 8
# Day              Friday
# Coffee Type    Espresso
# Units Sold           45
# Name: 8, dtype: object
#
#
# 9
# ...

# %% [markdown]
# ## Filtering Data

# %%
bios[(bios['height_cm'] > 215) & (bios['born_country'] == 'USA')]
# Out:
#         athlete_id              name   born_date  born_city     born_region  \
# 5781          5804    Tommy Burleson  1952-02-24  Crossnore  North Carolina
# 6722          6755  Shaquille O'Neal  1972-03-06     Newark      New Jersey
# 6937          6972    David Robinson  1965-08-06   Key West         Florida
# 123850      126093    Tyson Chandler  1982-10-02    Hanford      California
#
#        born_country            NOC  height_cm  weight_kg died_date
# 5781            USA  United States      223.0      102.0       NaN
# 6722            USA  United States      216.0      137.0       NaN
# 6937            USA  United States      216.0      107.0       NaN
# 123850          USA  United States      216.0      107.0       NaN

# %%
bios[bios['name'].str.contains("Chanu")]
# Out:
#         athlete_id                   name   born_date               born_city  \
# 11684        11745         Bertrand Chanu         NaN                     NaN
# 94172        94933        Sanamacha Chanu  1978-10-02                  Imphal
# 119716      121547  Soniya Chanu Ngangbam  1980-02-15                  Imphal
# 128070      130576          Mirabai Chanu  1994-08-08             Imphal East
# 131068      133830   Denis Gargaud Chanut  1987-07-22  Marseille (Marseilles)
#
#              born_region born_country     NOC  height_cm  weight_kg died_date
# 11684                NaN          NaN  France        NaN        NaN       NaN
# 94172            Manipur          IND   India      147.0       53.0       NaN
# 119716           Manipur          IND   India      149.0       48.0       NaN
# 128070           Manipur          IND   India      145.0       48.0       NaN
# 131068  Bouches-du-Rhône          FRA  France      181.0       76.0       NaN

# %%
bios.query('weight_kg > 120 and born_country == "IND"')
# Out:
#         athlete_id                      name   born_date born_city  \
# 70860        71391             Praveen Kumar  1947-12-06   Sirhali
# 119641      121467  Om Prakash Singh Karhana  1987-01-11   Gurgaon
#
#        born_region born_country    NOC  height_cm  weight_kg   died_date
# 70860       Punjab          IND  India      200.0      123.0  2022-02-07
# 119641     Haryana          IND  India      196.0      125.0         NaN

# %% [markdown]
# ## Adding / Removing Columns

# %%
coffee
coffee['price'] = 4.99

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold  price
# 0     Monday    Espresso          25   4.99
# 1     Monday       Latte          15   4.99
# 2    Tuesday    Espresso          30   4.99
# 3    Tuesday       Latte          20   4.99
# 4  Wednesday    Espresso          35   4.99

# %%
import numpy as np

coffee['new_price'] = np.where(coffee ['Coffee Type'] == 'Latte', 3.99, 5.99)

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold  new_price
# 0     Monday    Espresso         NaN       5.99
# 1     Monday       Latte         NaN       3.99
# 2    Tuesday    Espresso        30.0       5.99
# 3    Tuesday       Latte        20.0       3.99
# 4  Wednesday    Espresso        35.0       5.99

# %%
# coffee.drop(columns= ['price'], inplace= True)

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  new_price
# 0      Monday    Espresso         NaN       5.99
# 1      Monday       Latte         NaN       3.99
# 2     Tuesday    Espresso        30.0       5.99
# 3     Tuesday       Latte        20.0       3.99
# 4   Wednesday    Espresso        35.0       5.99
# 5   Wednesday       Latte        25.0       3.99
# 6    Thursday    Espresso        40.0       5.99
# 7    Thursday       Latte        30.0       3.99
# 8      Friday    Espresso        45.0       5.99
# 9      Friday       Latte        35.0       3.99
# 10   Saturday    Espresso        45.0       5.99
# 11   Saturday       Latte        35.0       3.99
# 12     Sunday    Espresso        45.0       5.99
# 13     Sunday       Latte        35.0       3.99

# %%
coffee['revenue'] = coffee['Units Sold'] * coffee['new_price']

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold  new_price  revenue
# 0     Monday    Espresso         NaN       5.99      NaN
# 1     Monday       Latte         NaN       3.99      NaN
# 2    Tuesday    Espresso        30.0       5.99   179.70
# 3    Tuesday       Latte        20.0       3.99    79.80
# 4  Wednesday    Espresso        35.0       5.99   209.65

# %%
coffee = coffee.rename(columns= {'new_price':'price'})

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  price  revenue
# 0      Monday    Espresso        15.0   5.99      NaN
# 1      Monday       Latte        15.0   3.99      NaN
# 2     Tuesday    Espresso         NaN   5.99   179.70
# 3     Tuesday       Latte         NaN   3.99    79.80
# 4   Wednesday    Espresso        15.0   5.99   209.65
# 5   Wednesday       Latte        25.0   3.99    99.75
# 6    Thursday    Espresso        40.0   5.99   239.60
# 7    Thursday       Latte        30.0   3.99   119.70
# 8      Friday    Espresso        45.0   5.99   269.55
# 9      Friday       Latte        35.0   3.99   139.65
# 10   Saturday    Espresso        45.0   5.99   269.55
# 11   Saturday       Latte        35.0   3.99   139.65
# 12     Sunday    Espresso        45.0   5.99   269.55
# 13     Sunday       Latte        35.0   3.99   139.65

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
bios_new = bios.copy()

# %%
bios_new['first_name'] = bios_new['name'].str.split(' ').str[0]

# %%
bios_new
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %%
bios_new[ 'born_datetime'] = pd.to_datetime(bios_new['born_date'])

# %%
bios_new['born_year'] = bios_new['born_datetime'].dt.year

bios_new[['name', 'born_year']]
# Out:
#                          name  born_year
# 0       Jean-François Blanchy     1886.0
# 1              Arnaud Boetsch     1969.0
# 2                Jean Borotra     1898.0
# 3             Jacques Brugnon     1895.0
# 4                Albert Canet     1878.0
# ...                       ...        ...
# 145495      Polina Luchnikova     2002.0
# 145496    Valeriya Merkusheva     1999.0
# 145497        Yuliya Smirnova     1998.0
# 145498         André Foussard     1899.0
# 145499          Bill Phillips     1913.0
#
# [145500 rows x 2 columns]

# %%
bios_new.to_csv('bios_new.csv', index= False)

# %%
def categorize_athlete(row):
    if row['height_cm'] < 175 and row ['weight_kg'] < 70:
        return 'LightWeight'
    elif row['height_cm'] < 185 and row ['weight_kg'] <= 80:
        return 'MiddleWeight'
    
    else:
        return 'HeavyWeight'
    
bios['category'] = bios.apply(categorize_athlete, axis = 1)

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date      category
# 0  1960-10-02   HeavyWeight
# 1         NaN  MiddleWeight
# 2  1994-07-17  MiddleWeight
# 3  1978-03-20   LightWeight
# 4  1930-07-25   HeavyWeight

# %% [markdown]
# ## Merging & Concatinating Data

# %%
nocs.head()
# Out:
#    NOC       region                 notes
# 0  AFG  Afghanistan                   NaN
# 1  AHO      Curacao  Netherlands Antilles
# 2  ALB      Albania                   NaN
# 3  ALG      Algeria                   NaN
# 4  AND      Andorra                   NaN

# %%
bios_new = pd.merge(bios, nocs, left_on = 'born_country', right_on= 'NOC', how = 'left')

# %%
bios_new.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country   NOC_x  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date NOC_y  region notes
# 0  1960-10-02   FRA  France   NaN
# 1         NaN   FRA  France   NaN
# 2  1994-07-17   FRA  France   NaN
# 3  1978-03-20   FRA  France   NaN
# ...

# %%
usa = bios[bios['born_country'] == 'USA'].copy()
gbr = bios[bios['born_country'] == 'GBR']. copy()
gbr.head()
# Out:
#     athlete_id               name   born_date    born_city born_region  \
# 4            5       Albert Canet  1878-04-17   Wandsworth     England
# 37          38    Helen Aitchison  1881-12-06   Sunderland     England
# 38          39  Geraldine Beamish  1883-06-23  Forest Gate     England
# 39          40       Dora Boothby  1881-08-02     Finchley     England
# 40          41     Julie Bradbury  1967-02-12       Oxford     England
#
#    born_country            NOC  height_cm  weight_kg   died_date
# 4           GBR         France        NaN        NaN  1930-07-25
# 37          GBR  Great Britain        NaN        NaN  1947-05-26
# 38          GBR  Great Britain        NaN        NaN  1972-05-10
# 39          GBR  Great Britain        NaN        NaN  1970-02-22
# 40          GBR  Great Britain      175.0       64.0         NaN

# %% [markdown]
# ## Handling Null Values

# %%
coffee.loc[[2,3], 'Units Sold'] = 15
coffee
# Out:
#           Day Coffee Type  Units Sold  price  revenue
# 0      Monday    Espresso        15.0   5.99      NaN
# 1      Monday       Latte        15.0   3.99      NaN
# 2     Tuesday    Espresso        15.0   5.99   179.70
# 3     Tuesday       Latte        15.0   3.99    79.80
# 4   Wednesday    Espresso        15.0   5.99   209.65
# 5   Wednesday       Latte        25.0   3.99    99.75
# 6    Thursday    Espresso        40.0   5.99   239.60
# 7    Thursday       Latte        30.0   3.99   119.70
# 8      Friday    Espresso        45.0   5.99   269.55
# 9      Friday       Latte        35.0   3.99   139.65
# 10   Saturday    Espresso        45.0   5.99   269.55
# 11   Saturday       Latte        35.0   3.99   139.65
# 12     Sunday    Espresso        45.0   5.99   269.55
# 13     Sunday       Latte        35.0   3.99   139.65

# %%
coffee.loc[[0, 1], 'revenue'] = coffee.loc[[0, 1], 'Units Sold'] * coffee.loc[[0, 1], 'price']

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  price  revenue
# 0      Monday    Espresso        15.0   5.99    89.85
# 1      Monday       Latte        15.0   3.99    59.85
# 2     Tuesday    Espresso        15.0   5.99   179.70
# 3     Tuesday       Latte        15.0   3.99    79.80
# 4   Wednesday    Espresso        15.0   5.99   209.65
# 5   Wednesday       Latte        25.0   3.99    99.75
# 6    Thursday    Espresso        40.0   5.99   239.60
# 7    Thursday       Latte        30.0   3.99   119.70
# 8      Friday    Espresso        45.0   5.99   269.55
# 9      Friday       Latte        35.0   3.99   139.65
# 10   Saturday    Espresso        45.0   5.99   269.55
# 11   Saturday       Latte        35.0   3.99   139.65
# 12     Sunday    Espresso        45.0   5.99   269.55
# 13     Sunday       Latte        35.0   3.99   139.65

# %%
coffee[coffee['Units Sold'].notna()]
# Out:
#           Day Coffee Type  Units Sold  price  revenue
# 0      Monday    Espresso        15.0   5.99    89.85
# 1      Monday       Latte        15.0   3.99    59.85
# 2     Tuesday    Espresso        15.0   5.99   179.70
# 3     Tuesday       Latte        15.0   3.99    79.80
# 4   Wednesday    Espresso        15.0   5.99   209.65
# 5   Wednesday       Latte        25.0   3.99    99.75
# 6    Thursday    Espresso        40.0   5.99   239.60
# 7    Thursday       Latte        30.0   3.99   119.70
# 8      Friday    Espresso        45.0   5.99   269.55
# 9      Friday       Latte        35.0   3.99   139.65
# 10   Saturday    Espresso        45.0   5.99   269.55
# 11   Saturday       Latte        35.0   3.99   139.65
# 12     Sunday    Espresso        45.0   5.99   269.55
# 13     Sunday       Latte        35.0   3.99   139.65

# %% [markdown]
# ## Aggregating Data

# %%
bios
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %%
bios[bios['born_country']=='USA']['born_region']. value_counts()
# Out:
# born_region
# California              1634
# New York                 990
# Illinois                 585
# Massachusetts            530
# Pennsylvania             530
# New Jersey               381
# Texas                    368
# Minnesota                365
# Ohio                     328
# Michigan                 319
# Washington               240
# Florida                  235
# Wisconsin                209
# Colorado                 207
# Connecticut              156
# Indiana                  150
# Oregon                   132
# Georgia                  129
# Virginia                 121
# Maryland                 117
# District of Columbia     107
# Iowa                     102
# Hawaiʻi                   95
# Kansas                    94
# Oklahoma                  93
# Louisiana                 92
# Utah                      91
# Missouri                  91
# North Carolina            86
# Arizona                   83
# New Hampshire             83
# ...

# %%
coffee['Units Sold'] = coffee['Units Sold'].interpolate()

# %%
coffee.groupby(['Coffee Type']) ['Units Sold'].sum()
# Out:
# Coffee Type
# Espresso    220.0
# Latte       190.0
# Name: Units Sold, dtype: float64

# %%
coffee.groupby(['Coffee Type']).agg({'Units Sold': 'sum', 'price': 'mean'})
# Out:
#              Units Sold  price
# Coffee Type
# Espresso          220.0   5.99
# Latte             190.0   3.99

# %%
pivot = coffee.pivot(columns= 'Coffee Type', index='Day', values='revenue')

# %%
pivot
# Out:
# Coffee Type  Espresso   Latte
# Day
# Friday         269.55  139.65
# Monday          89.85   59.85
# Saturday       269.55  139.65
# Sunday         269.55  139.65
# Thursday       239.60  119.70
# Tuesday        179.70   79.80
# Wednesday      209.65   99.75

# %%
pivot.sum()
# Out:
# Coffee Type
# Espresso    1527.45
# Latte        778.05
# dtype: float64

# %%
bios['born_date'] = pd.to_datetime(bios['born_date'])

bios.groupby(bios['born_date'].dt.year)['name'].count().reset_index().sort_values('name', ascending= False)
# Out:
#      born_date  name
# 139     1972.0  2231
# 152     1985.0  2227
# 140     1973.0  2216
# 138     1971.0  2205
# 137     1970.0  2174
# ..         ...   ...
# 4       1837.0     1
# 2       1833.0     1
# 6       1839.0     1
# 12      1845.0     1
# 176     2009.0     1
#
# [177 rows x 2 columns]

# %% [markdown]
# ## Advanced Functionality

# %%
coffee['yesterday_revenue'] = coffee['revenue'].shift(2)

# %%
coffee['pct_change'] = coffee['revenue'] / coffee['yesterday_revenue'] * 100

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  price  revenue  yesterday_revenue  \
# 0      Monday    Espresso        15.0   5.99    89.85                NaN
# 1      Monday       Latte        15.0   3.99    59.85                NaN
# 2     Tuesday    Espresso        15.0   5.99   179.70              89.85
# 3     Tuesday       Latte        15.0   3.99    79.80              59.85
# 4   Wednesday    Espresso        15.0   5.99   209.65             179.70
# 5   Wednesday       Latte        25.0   3.99    99.75              79.80
# 6    Thursday    Espresso        40.0   5.99   239.60             209.65
# 7    Thursday       Latte        30.0   3.99   119.70              99.75
# 8      Friday    Espresso        45.0   5.99   269.55             239.60
# 9      Friday       Latte        35.0   3.99   139.65             119.70
# 10   Saturday    Espresso        45.0   5.99   269.55             269.55
# 11   Saturday       Latte        35.0   3.99   139.65             139.65
# ...

# %%
coffee['cumulative_revenue'] = coffee['revenue'].cumsum()

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  price  revenue  yesterday_revenue  \
# 0      Monday    Espresso        15.0   5.99    89.85                NaN
# 1      Monday       Latte        15.0   3.99    59.85                NaN
# 2     Tuesday    Espresso        15.0   5.99   179.70              89.85
# 3     Tuesday       Latte        15.0   3.99    79.80              59.85
# 4   Wednesday    Espresso        15.0   5.99   209.65             179.70
# 5   Wednesday       Latte        25.0   3.99    99.75              79.80
# 6    Thursday    Espresso        40.0   5.99   239.60             209.65
# 7    Thursday       Latte        30.0   3.99   119.70              99.75
# 8      Friday    Espresso        45.0   5.99   269.55             239.60
# 9      Friday       Latte        35.0   3.99   139.65             119.70
# 10   Saturday    Espresso        45.0   5.99   269.55             269.55
# 11   Saturday       Latte        35.0   3.99   139.65             139.65
# ...

# %%
bios.head()
# Out:
#    athlete_id                   name  born_date    born_city  \
# 0           1  Jean-François Blanchy 1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch 1969-04-01       Meulan
# 2           3           Jean Borotra 1898-08-13     Biarritz
# 3           4        Jacques Brugnon 1895-05-11  Paris VIIIe
# 4           5           Albert Canet 1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# ...

# %% [markdown]
# ## END OF the session
